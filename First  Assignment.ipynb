# %% [markdown]
# # 1. STUDENT INFORMATION

# %%
student_name= "Daniyal Shahid"
age = 19
city = "Karachi"
student_status= "Active status"

print("Student information")
print("Name:", student_name)
print("Age:", age)
print("city:",city)
print("Status:", student_status)
# Out:
# Student information
# Name: Daniyal Shahid
# Age: 19
# city: Karachi
# Status: Active status

# %% [markdown]
# # 2. DATA TYPE

# %%
name = "Daniyal Shahid"
age = 19
marks = 89
student = True

print("Value:", name, "| Type:", type(name))
print("Value:", age, "| Type:", type(age))
print("Value:", marks, "| Type:", type(marks))
print("Value:", student, "| Type:", type(student))
# Out:
# Value: Daniyal Shahid | Type: <class 'str'>
# Value: 19 | Type: <class 'int'>
# Value: 89 | Type: <class 'int'>
# Value: True | Type: <class 'bool'>

# %% [markdown]
# # 3. ARITHMETIC OPERATION

# %%
a = 30
b = 14

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Modulus:", a % b)
print("Power:", a ** b)
# Out:
# Addition: 44
# Subtraction: 16
# Multiplication: 420
# Division: 2.142857142857143
# Modulus: 2
# Power: 478296900000000000000

# %% [markdown]
# # 4. STUDENT MARKS CALCULATOR

# %%
physics = 80.5
mathematics = 73
computer_science = 88

total_marks = physics + mathematics + computer_science
average_marks = total_marks / 3

print("physics:",physics)
print("Mathematics:", mathematics)
print("Computer_science:", computer_science)
print("Total Marks:", total_marks)
print("Average Marks:", average_marks)
# Out:
# physics: 80.5
# Mathematics: 73
# Computer_science: 88
# Total Marks: 241.5
# Average Marks: 80.5

# %% [markdown]
# # 5. SHOPPING BILL

# %%
product_price =2750
quantity = 6

total_bill = product_price* quantity

print("Product Price:", product_price)
print("Quantity:", quantity)
print("Total Bill:", total_bill)
# Out:
# Product Price: 2750
# Quantity: 6
# Total Bill: 16500

# %% [markdown]
# # 6. RECTANGLE AERA

# %%
length = 15
width = 10

area = length * width
perimeter = 2 * (length + width)

print("Length:", length)
print("Width:", width)
print("Area:", area)
print("Perimeter:", perimeter)
# Out:
# Length: 15
# Width: 10
# Area: 150
# Perimeter: 50

# %% [markdown]
# # 7. TIME CONVERTER

# %%
minutes = 1280

hours = minutes // 60
remaining_minutes = minutes % 60

print("Total Minutes:", minutes)
print("Hours:", hours)
print("Remaining Minutes:", remaining_minutes)
# Out:
# Total Minutes: 1280
# Hours: 21
# Remaining Minutes: 20

# %% [markdown]
# # 8. STUDENT ELIGIBILITY

# %%
marks = 79
attendance = 100 

eligible = (marks >= 45 ) and (attendance >= 85 )

print("Marks:", marks)
print("Attendance:", attendance)
print("Student Eligible:", eligible)
# Out:
# Marks: 79
# Attendance: 100
# Student Eligible: True

# %% [markdown]
# # 9. LOGICAL OPERATION

# %%
a = False
b = True

print("a and b:", a and b)
print("a or b:", a or b)
print("not a:", not a)
print("not b:", not b)
# Out:
# a and b: False
# a or b: True
# not a: True
# not b: False

# %% [markdown]
# # 10. FINAL ASSIGMENT _ STUDENT REPORT

# %%
student_name = "Daniyal Shahid"
age = 19

physics = 80.5
mathematics = 73 
computer_science = 88

attendance = 75

total_marks = physics + mathematics + computer_science
average_marks = total_marks / 3

eligible = (average_marks >= 50) and (attendance >= 75)

print("========== STUDENT REPORT ==========")

print("Student Name:", student_name)
print("Age:", age)

print("Physics Marks:", physics)
print("Mathematics Marks:", mathematics)
print("Computer_science Marks:", computer)

print("Attendance:", attendance)

print("Total Marks:", total_marks)
print("Average Marks:", average_marks)

print("Student Eligible:", eligible)

print("====================================")
# Out:
# ========== STUDENT REPORT ==========
# Student Name: Daniyal Shahid
# Age: 19
# Physics Marks: 80.5
# Mathematics Marks: 73
# Computer_science Marks: 88
# Attendance: 75
# Total Marks: 241.5
# Average Marks: 80.5
# Student Eligible: True
# ...
